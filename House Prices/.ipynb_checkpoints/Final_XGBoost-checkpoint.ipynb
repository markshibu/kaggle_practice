# %%
import pandas as pd
from sklearn.preprocessing import Imputer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')

# %%
# Drop all rows with missing data on column 'SalePrice'
data = data.dropna(axis=0, how='any',subset=['SalePrice'])

# %%
y = data.SalePrice
X = data.drop(['SalePrice'],axis=1).select_dtypes(exclude=['object'])

# %% [markdown]
# ## Handling Missing Data

# %%
def missing_data_marker(df):
    cols_with_missing = (col for col in df.columns if df[col].isnull().any())
    for col in cols_with_missing:
        df[col+'_was_missing'] = df[col].isnull()
    return df

# %%
X = missing_data_marker(X)

# %%
from sklearn.preprocessing import Imputer

my_imputer = Imputer()
X = my_imputer.fit_transform(X)

# %% [markdown]
# ## Model Tuning

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor(n_estimators=3000, learning_rate=0.01, n_jobs=4)
early_stopping_rounds = 5
my_model.fit(train_X, train_y, early_stopping_rounds=early_stopping_rounds, 
             eval_set=[(test_X, test_y)], verbose=True)
# Out:
# [0]	validation_0-rmse:197950
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:196165
# [2]	validation_0-rmse:194400
# [3]	validation_0-rmse:192654
# [4]	validation_0-rmse:190938
# [5]	validation_0-rmse:189227
# [6]	validation_0-rmse:187547
# [7]	validation_0-rmse:185870
# [8]	validation_0-rmse:184213
# [9]	validation_0-rmse:182584
# [10]	validation_0-rmse:180961
# [11]	validation_0-rmse:179366
# [12]	validation_0-rmse:177778
# [13]	validation_0-rmse:176213
# [14]	validation_0-rmse:174652
# [15]	validation_0-rmse:173125
# [16]	validation_0-rmse:171595
# [17]	validation_0-rmse:170071
# [18]	validation_0-rmse:168593
# [19]	validation_0-rmse:167116
# [20]	validation_0-rmse:165637
# [21]	validation_0-rmse:164188
# [22]	validation_0-rmse:162762
# [23]	validation_0-rmse:161333
# [24]	validation_0-rmse:159942
# [25]	validation_0-rmse:158539
# [26]	validation_0-rmse:157167
# [27]	validation_0-rmse:155810
# [28]	validation_0-rmse:154459
# [29]	validation_0-rmse:153139
# [30]	validation_0-rmse:151837
# [31]	validation_0-rmse:150482
# [32]	validation_0-rmse:149186
# [33]	validation_0-rmse:147914
# [34]	validation_0-rmse:146645
# [35]	validation_0-rmse:145392
# [36]	validation_0-rmse:144152
# [37]	validation_0-rmse:142935
# [38]	validation_0-rmse:141684
# [39]	validation_0-rmse:140500
# [40]	validation_0-rmse:139318
# [41]	validation_0-rmse:138131
# [42]	validation_0-rmse:136976
# [43]	validation_0-rmse:135837
# [44]	validation_0-rmse:134684
# [45]	validation_0-rmse:133567
# [46]	validation_0-rmse:132438
# [47]	validation_0-rmse:131308
# [48]	validation_0-rmse:130223
# [49]	validation_0-rmse:129118
# [50]	validation_0-rmse:128053
# [51]	validation_0-rmse:126970
# [52]	validation_0-rmse:125933
# [53]	validation_0-rmse:124878
# [54]	validation_0-rmse:123872
# [55]	validation_0-rmse:122829
# [56]	validation_0-rmse:121839
# [57]	validation_0-rmse:120813
# [58]	validation_0-rmse:119807
# [59]	validation_0-rmse:118833
# [60]	validation_0-rmse:117840
# [61]	validation_0-rmse:116904
# [62]	validation_0-rmse:115931
# [63]	validation_0-rmse:115004
# [64]	validation_0-rmse:114057
# [65]	validation_0-rmse:113154
# [66]	validation_0-rmse:112221
# [67]	validation_0-rmse:111341
# [68]	validation_0-rmse:110441
# [69]	validation_0-rmse:109551
# [70]	validation_0-rmse:108701
# [71]	validation_0-rmse:107819
# [72]	validation_0-rmse:106957
# [73]	validation_0-rmse:106136
# [74]	validation_0-rmse:105278
# [75]	validation_0-rmse:104472
# [76]	validation_0-rmse:103646
# [77]	validation_0-rmse:102815
# [78]	validation_0-rmse:102036
# [79]	validation_0-rmse:101245
# [80]	validation_0-rmse:100462
# [81]	validation_0-rmse:99680.5
# [82]	validation_0-rmse:98948.9
# [83]	validation_0-rmse:98167.3
# [84]	validation_0-rmse:97431.8
# [85]	validation_0-rmse:96684.9
# [86]	validation_0-rmse:95928.5
# [87]	validation_0-rmse:95207.5
# [88]	validation_0-rmse:94482.7
# [89]	validation_0-rmse:93782.2
# [90]	validation_0-rmse:93069.7
# [91]	validation_0-rmse:92345.1
# [92]	validation_0-rmse:91628.8
# [93]	validation_0-rmse:90949.8
# [94]	validation_0-rmse:90262.3
# [95]	validation_0-rmse:89569.3
# [96]	validation_0-rmse:88934.6
# [97]	validation_0-rmse:88270
# [98]	validation_0-rmse:87610.9
# [99]	validation_0-rmse:86965.5
# [100]	validation_0-rmse:86307
# [101]	validation_0-rmse:85671.8
# [102]	validation_0-rmse:85017.3
# [103]	validation_0-rmse:84376.9
# [104]	validation_0-rmse:83761.6
# [105]	validation_0-rmse:83180.4
# [106]	validation_0-rmse:82565.1
# [107]	validation_0-rmse:81960.9
# [108]	validation_0-rmse:81400.5
# [109]	validation_0-rmse:80800.9
# [110]	validation_0-rmse:80224.1
# [111]	validation_0-rmse:79682.7
# [112]	validation_0-rmse:79110.7
# [113]	validation_0-rmse:78581.1
# [114]	validation_0-rmse:78011.9
# [115]	validation_0-rmse:77494.6
# [116]	validation_0-rmse:76966.5
# [117]	validation_0-rmse:76421
# [118]	validation_0-rmse:75908.7
# [119]	validation_0-rmse:75362.9
# [120]	validation_0-rmse:74858.1
# [121]	validation_0-rmse:74371.9
# [122]	validation_0-rmse:73875.8
# [123]	validation_0-rmse:73353.5
# [124]	validation_0-rmse:72861.5
# [125]	validation_0-rmse:72388.6
# [126]	validation_0-rmse:71884.9
# [127]	validation_0-rmse:71434.4
# [128]	validation_0-rmse:70970.6
# [129]	validation_0-rmse:70506.6
# [130]	validation_0-rmse:70059.4
# [131]	validation_0-rmse:69585.3
# [132]	validation_0-rmse:69153.2
# [133]	validation_0-rmse:68729.2
# [134]	validation_0-rmse:68298.9
# [135]	validation_0-rmse:67873.3
# [136]	validation_0-rmse:67419.6
# [137]	validation_0-rmse:66978.6
# [138]	validation_0-rmse:66578
# [139]	validation_0-rmse:66182.2
# [140]	validation_0-rmse:65780.8
# [141]	validation_0-rmse:65349.3
# [142]	validation_0-rmse:64931.8
# [143]	validation_0-rmse:64553.7
# [144]	validation_0-rmse:64165.2
# [145]	validation_0-rmse:63782.2
# [146]	validation_0-rmse:63372.1
# [147]	validation_0-rmse:63006.8
# [148]	validation_0-rmse:62640.4
# [149]	validation_0-rmse:62282.8
# [150]	validation_0-rmse:61893.7
# [151]	validation_0-rmse:61561.8
# [152]	validation_0-rmse:61232
# [153]	validation_0-rmse:60909.2
# [154]	validation_0-rmse:60573.2
# [155]	validation_0-rmse:60235
# [156]	validation_0-rmse:59881.1
# [157]	validation_0-rmse:59556.4
# [158]	validation_0-rmse:59203
# [159]	validation_0-rmse:58886.2
# [160]	validation_0-rmse:58567.1
# [161]	validation_0-rmse:58225.1
# [162]	validation_0-rmse:57900.3
# [163]	validation_0-rmse:57594.4
# [164]	validation_0-rmse:57289.4
# [165]	validation_0-rmse:56964.6
# [166]	validation_0-rmse:56665.7
# [167]	validation_0-rmse:56372.9
# [168]	validation_0-rmse:56059.1
# [169]	validation_0-rmse:55751.6
# [170]	validation_0-rmse:55466.7
# [171]	validation_0-rmse:55161.2
# [172]	validation_0-rmse:54895.9
# [173]	validation_0-rmse:54606.6
# [174]	validation_0-rmse:54315.6
# [175]	validation_0-rmse:54047.6
# [176]	validation_0-rmse:53785.8
# [177]	validation_0-rmse:53523.3
# [178]	validation_0-rmse:53254.6
# [179]	validation_0-rmse:53000.4
# [180]	validation_0-rmse:52765
# [181]	validation_0-rmse:52536.9
# [182]	validation_0-rmse:52307.9
# [183]	validation_0-rmse:52040.2
# [184]	validation_0-rmse:51799.9
# [185]	validation_0-rmse:51573.3
# [186]	validation_0-rmse:51312.4
# [187]	validation_0-rmse:51080.2
# [188]	validation_0-rmse:50867.7
# [189]	validation_0-rmse:50614.2
# [190]	validation_0-rmse:50370
# [191]	validation_0-rmse:50159.3
# [192]	validation_0-rmse:49959
# [193]	validation_0-rmse:49717
# [194]	validation_0-rmse:49478
# [195]	validation_0-rmse:49268
# [196]	validation_0-rmse:49073.5
# [197]	validation_0-rmse:48867.7
# [198]	validation_0-rmse:48669.2
# [199]	validation_0-rmse:48446.5
# [200]	validation_0-rmse:48232.3
# [201]	validation_0-rmse:48045
# [202]	validation_0-rmse:47827.6
# [203]	validation_0-rmse:47656.9
# [204]	validation_0-rmse:47452.8
# [205]	validation_0-rmse:47274.2
# [206]	validation_0-rmse:47094.1
# [207]	validation_0-rmse:46905.9
# [208]	validation_0-rmse:46698.9
# [209]	validation_0-rmse:46512.1
# [210]	validation_0-rmse:46340.8
# [211]	validation_0-rmse:46159
# [212]	validation_0-rmse:46000.6
# [213]	validation_0-rmse:45835.7
# [214]	validation_0-rmse:45661.5
# [215]	validation_0-rmse:45494.1
# [216]	validation_0-rmse:45335.4
# [217]	validation_0-rmse:45180.3
# [218]	validation_0-rmse:45021.1
# [219]	validation_0-rmse:44874.7
# [220]	validation_0-rmse:44725.3
# [221]	validation_0-rmse:44575.9
# [222]	validation_0-rmse:44417.9
# [223]	validation_0-rmse:44274.1
# [224]	validation_0-rmse:44130.6
# [225]	validation_0-rmse:43976.6
# [226]	validation_0-rmse:43842.5
# [227]	validation_0-rmse:43701.4
# [228]	validation_0-rmse:43571.9
# [229]	validation_0-rmse:43427.2
# [230]	validation_0-rmse:43270.3
# [231]	validation_0-rmse:43127
# [232]	validation_0-rmse:43002.7
# [233]	validation_0-rmse:42876
# [234]	validation_0-rmse:42749.1
# [235]	validation_0-rmse:42612
# [236]	validation_0-rmse:42489.4
# [237]	validation_0-rmse:42370.8
# [238]	validation_0-rmse:42255.6
# [239]	validation_0-rmse:42132
# [240]	validation_0-rmse:42015.4
# [241]	validation_0-rmse:41896.6
# [242]	validation_0-rmse:41792.3
# [243]	validation_0-rmse:41674.1
# [244]	validation_0-rmse:41532.2
# [245]	validation_0-rmse:41415.1
# [246]	validation_0-rmse:41283.7
# [247]	validation_0-rmse:41164.4
# [248]	validation_0-rmse:41060.9
# [249]	validation_0-rmse:40946.1
# [250]	validation_0-rmse:40837.9
# [251]	validation_0-rmse:40714
# [252]	validation_0-rmse:40629.8
# [253]	validation_0-rmse:40532.2
# [254]	validation_0-rmse:40424.4
# [255]	validation_0-rmse:40329.6
# [256]	validation_0-rmse:40243.3
# [257]	validation_0-rmse:40144.2
# [258]	validation_0-rmse:40053
# [259]	validation_0-rmse:39969.5
# [260]	validation_0-rmse:39868.7
# [261]	validation_0-rmse:39780.5
# [262]	validation_0-rmse:39681.3
# [263]	validation_0-rmse:39602.3
# [264]	validation_0-rmse:39517.6
# [265]	validation_0-rmse:39422.9
# [266]	validation_0-rmse:39347.2
# [267]	validation_0-rmse:39262.9
# [268]	validation_0-rmse:39168.6
# [269]	validation_0-rmse:39068.5
# [270]	validation_0-rmse:38979
# [271]	validation_0-rmse:38895.1
# [272]	validation_0-rmse:38830.8
# [273]	validation_0-rmse:38735
# [274]	validation_0-rmse:38660.3
# [275]	validation_0-rmse:38563.7
# [276]	validation_0-rmse:38477.9
# [277]	validation_0-rmse:38403.1
# [278]	validation_0-rmse:38309.7
# [279]	validation_0-rmse:38242.7
# [280]	validation_0-rmse:38171.5
# [281]	validation_0-rmse:38106.1
# [282]	validation_0-rmse:38044.7
# [283]	validation_0-rmse:37966.7
# [284]	validation_0-rmse:37878.8
# [285]	validation_0-rmse:37817.2
# [286]	validation_0-rmse:37764.7
# [287]	validation_0-rmse:37707
# [288]	validation_0-rmse:37652.9
# [289]	validation_0-rmse:37569.3
# [290]	validation_0-rmse:37514.7
# [291]	validation_0-rmse:37462.8
# [292]	validation_0-rmse:37385.1
# [293]	validation_0-rmse:37315
# [294]	validation_0-rmse:37261
# [295]	validation_0-rmse:37213.6
# [296]	validation_0-rmse:37158.3
# [297]	validation_0-rmse:37088.1
# [298]	validation_0-rmse:37040.7
# [299]	validation_0-rmse:36996.2
# [300]	validation_0-rmse:36950.1
# [301]	validation_0-rmse:36882.8
# [302]	validation_0-rmse:36840.4
# [303]	validation_0-rmse:36796.2
# [304]	validation_0-rmse:36725
# [305]	validation_0-rmse:36681.7
# [306]	validation_0-rmse:36623.9
# [307]	validation_0-rmse:36578.1
# [308]	validation_0-rmse:36505.5
# [309]	validation_0-rmse:36433.3
# [310]	validation_0-rmse:36392.9
# [311]	validation_0-rmse:36327.1
# [312]	validation_0-rmse:36281.6
# [313]	validation_0-rmse:36221.2
# [314]	validation_0-rmse:36178.2
# [315]	validation_0-rmse:36110.5
# [316]	validation_0-rmse:36058.9
# [317]	validation_0-rmse:36024.9
# [318]	validation_0-rmse:35986.5
# [319]	validation_0-rmse:35946.9
# [320]	validation_0-rmse:35882.2
# [321]	validation_0-rmse:35829.2
# [322]	validation_0-rmse:35797.8
# [323]	validation_0-rmse:35760.8
# [324]	validation_0-rmse:35725.4
# [325]	validation_0-rmse:35670.5
# [326]	validation_0-rmse:35609
# [327]	validation_0-rmse:35556.9
# [328]	validation_0-rmse:35522.5
# [329]	validation_0-rmse:35473.5
# [330]	validation_0-rmse:35421.2
# [331]	validation_0-rmse:35372.5
# [332]	validation_0-rmse:35339.7
# [333]	validation_0-rmse:35313.3
# [334]	validation_0-rmse:35256.1
# [335]	validation_0-rmse:35210.3
# [336]	validation_0-rmse:35179.1
# [337]	validation_0-rmse:35129.5
# [338]	validation_0-rmse:35082.7
# [339]	validation_0-rmse:35039.2
# [340]	validation_0-rmse:34979.7
# [341]	validation_0-rmse:34949.9
# [342]	validation_0-rmse:34927.2
# [343]	validation_0-rmse:34900
# [344]	validation_0-rmse:34856.5
# [345]	validation_0-rmse:34797.9
# [346]	validation_0-rmse:34754.8
# [347]	validation_0-rmse:34727.1
# [348]	validation_0-rmse:34688.9
# [349]	validation_0-rmse:34641.3
# [350]	validation_0-rmse:34614.4
# [351]	validation_0-rmse:34560.4
# [352]	validation_0-rmse:34506.3
# [353]	validation_0-rmse:34467.9
# [354]	validation_0-rmse:34449
# [355]	validation_0-rmse:34410.8
# [356]	validation_0-rmse:34359
# [357]	validation_0-rmse:34316.5
# [358]	validation_0-rmse:34278
# [359]	validation_0-rmse:34226.5
# [360]	validation_0-rmse:34194
# [361]	validation_0-rmse:34158.9
# [362]	validation_0-rmse:34121.9
# [363]	validation_0-rmse:34086.9
# [364]	validation_0-rmse:34063.2
# [365]	validation_0-rmse:34014.6
# [366]	validation_0-rmse:33982
# [367]	validation_0-rmse:33967.1
# [368]	validation_0-rmse:33937.1
# [369]	validation_0-rmse:33914.6
# [370]	validation_0-rmse:33889
# [371]	validation_0-rmse:33842.5
# [372]	validation_0-rmse:33803.9
# [373]	validation_0-rmse:33772.5
# [374]	validation_0-rmse:33740
# [375]	validation_0-rmse:33722.7
# [376]	validation_0-rmse:33677.8
# [377]	validation_0-rmse:33649.8
# [378]	validation_0-rmse:33620.7
# [379]	validation_0-rmse:33589.4
# [380]	validation_0-rmse:33556.4
# [381]	validation_0-rmse:33513.1
# [382]	validation_0-rmse:33482.8
# [383]	validation_0-rmse:33463.5
# [384]	validation_0-rmse:33418.4
# [385]	validation_0-rmse:33406
# [386]	validation_0-rmse:33377.3
# [387]	validation_0-rmse:33335.6
# [388]	validation_0-rmse:33309.8
# [389]	validation_0-rmse:33265.3
# [390]	validation_0-rmse:33239.3
# [391]	validation_0-rmse:33225.4
# [392]	validation_0-rmse:33184.4
# [393]	validation_0-rmse:33174.7
# [394]	validation_0-rmse:33153.6
# [395]	validation_0-rmse:33140.4
# [396]	validation_0-rmse:33116.6
# [397]	validation_0-rmse:33092.1
# [398]	validation_0-rmse:33054.6
# [399]	validation_0-rmse:33031.7
# [400]	validation_0-rmse:33006.5
# [401]	validation_0-rmse:32963.8
# [402]	validation_0-rmse:32931.8
# [403]	validation_0-rmse:32908.2
# [404]	validation_0-rmse:32885.6
# [405]	validation_0-rmse:32861.9
# [406]	validation_0-rmse:32850.4
# [407]	validation_0-rmse:32812.7
# [408]	validation_0-rmse:32790.2
# [409]	validation_0-rmse:32769.1
# [410]	validation_0-rmse:32744
# [411]	validation_0-rmse:32719.9
# [412]	validation_0-rmse:32709.2
# [413]	validation_0-rmse:32671.9
# [414]	validation_0-rmse:32650.5
# [415]	validation_0-rmse:32634.1
# [416]	validation_0-rmse:32620.4
# [417]	validation_0-rmse:32597.3
# [418]	validation_0-rmse:32561.3
# [419]	validation_0-rmse:32545.7
# [420]	validation_0-rmse:32526.3
# [421]	validation_0-rmse:32492.5
# [422]	validation_0-rmse:32477.4
# [423]	validation_0-rmse:32455.8
# [424]	validation_0-rmse:32446.2
# [425]	validation_0-rmse:32431.8
# [426]	validation_0-rmse:32400.2
# [427]	validation_0-rmse:32378.3
# [428]	validation_0-rmse:32359.9
# [429]	validation_0-rmse:32341.4
# [430]	validation_0-rmse:32329.7
# [431]	validation_0-rmse:32297.7
# [432]	validation_0-rmse:32284.2
# [433]	validation_0-rmse:32269.8
# [434]	validation_0-rmse:32255.7
# [435]	validation_0-rmse:32244.4
# [436]	validation_0-rmse:32221.3
# [437]	validation_0-rmse:32207.5
# [438]	validation_0-rmse:32194
# [439]	validation_0-rmse:32176.5
# [440]	validation_0-rmse:32165.3
# [441]	validation_0-rmse:32133.6
# [442]	validation_0-rmse:32123.2
# [443]	validation_0-rmse:32097.8
# [444]	validation_0-rmse:32086.2
# [445]	validation_0-rmse:32079.6
# [446]	validation_0-rmse:32068.3
# [447]	validation_0-rmse:32047.7
# [448]	validation_0-rmse:32019.4
# [449]	validation_0-rmse:31997.7
# [450]	validation_0-rmse:31970.1
# [451]	validation_0-rmse:31960
# [452]	validation_0-rmse:31941.2
# [453]	validation_0-rmse:31915
# [454]	validation_0-rmse:31905.7
# [455]	validation_0-rmse:31884.4
# [456]	validation_0-rmse:31865.7
# [457]	validation_0-rmse:31857.2
# [458]	validation_0-rmse:31848.9
# [459]	validation_0-rmse:31837.5
# [460]	validation_0-rmse:31831
# [461]	validation_0-rmse:31823
# [462]	validation_0-rmse:31816.7
# [463]	validation_0-rmse:31805.6
# [464]	validation_0-rmse:31797.9
# [465]	validation_0-rmse:31785.1
# [466]	validation_0-rmse:31761.4
# [467]	validation_0-rmse:31752.5
# [468]	validation_0-rmse:31736
# [469]	validation_0-rmse:31716.2
# [470]	validation_0-rmse:31710.5
# [471]	validation_0-rmse:31701.9
# [472]	validation_0-rmse:31694
# [473]	validation_0-rmse:31676.2
# [474]	validation_0-rmse:31673.1
# [475]	validation_0-rmse:31666.2
# [476]	validation_0-rmse:31654.4
# [477]	validation_0-rmse:31647.9
# [478]	validation_0-rmse:31623.5
# [479]	validation_0-rmse:31606.3
# [480]	validation_0-rmse:31580.5
# [481]	validation_0-rmse:31569.7
# [482]	validation_0-rmse:31560.7
# [483]	validation_0-rmse:31555.8
# [484]	validation_0-rmse:31543.4
# [485]	validation_0-rmse:31530.7
# [486]	validation_0-rmse:31522
# [487]	validation_0-rmse:31506.9
# [488]	validation_0-rmse:31501
# [489]	validation_0-rmse:31490.7
# [490]	validation_0-rmse:31476.7
# [491]	validation_0-rmse:31455.8
# [492]	validation_0-rmse:31439.5
# [493]	validation_0-rmse:31432.4
# [494]	validation_0-rmse:31425.1
# [495]	validation_0-rmse:31402.8
# [496]	validation_0-rmse:31402.7
# [497]	validation_0-rmse:31377.9
# [498]	validation_0-rmse:31368
# [499]	validation_0-rmse:31346.1
# [500]	validation_0-rmse:31339.4
# [501]	validation_0-rmse:31346
# [502]	validation_0-rmse:31324.3
# [503]	validation_0-rmse:31326.1
# [504]	validation_0-rmse:31306.6
# [505]	validation_0-rmse:31299.4
# [506]	validation_0-rmse:31290.1
# [507]	validation_0-rmse:31268.9
# [508]	validation_0-rmse:31242.8
# [509]	validation_0-rmse:31236.8
# [510]	validation_0-rmse:31216
# [511]	validation_0-rmse:31206.9
# [512]	validation_0-rmse:31187.3
# [513]	validation_0-rmse:31177.8
# [514]	validation_0-rmse:31159.3
# [515]	validation_0-rmse:31152.6
# [516]	validation_0-rmse:31139.3
# [517]	validation_0-rmse:31120.2
# [518]	validation_0-rmse:31097.5
# [519]	validation_0-rmse:31086.9
# [520]	validation_0-rmse:31067
# [521]	validation_0-rmse:31060.5
# [522]	validation_0-rmse:31042
# [523]	validation_0-rmse:31031.6
# [524]	validation_0-rmse:31022.7
# [525]	validation_0-rmse:31013.2
# [526]	validation_0-rmse:31000.5
# [527]	validation_0-rmse:30976.5
# [528]	validation_0-rmse:30967.2
# [529]	validation_0-rmse:30950
# [530]	validation_0-rmse:30940.4
# [531]	validation_0-rmse:30928.1
# [532]	validation_0-rmse:30925.7
# [533]	validation_0-rmse:30915.9
# [534]	validation_0-rmse:30907.4
# [535]	validation_0-rmse:30899.1
# [536]	validation_0-rmse:30893.7
# [537]	validation_0-rmse:30881.8
# [538]	validation_0-rmse:30894
# [539]	validation_0-rmse:30886.6
# [540]	validation_0-rmse:30869.3
# [541]	validation_0-rmse:30881.5
# [542]	validation_0-rmse:30881.4
# [543]	validation_0-rmse:30876.7
# [544]	validation_0-rmse:30869.9
# [545]	validation_0-rmse:30858.5
# [546]	validation_0-rmse:30840.2
# [547]	validation_0-rmse:30852.4
# [548]	validation_0-rmse:30845.1
# [549]	validation_0-rmse:30836.8
# [550]	validation_0-rmse:30824.9
# [551]	validation_0-rmse:30817
# [552]	validation_0-rmse:30798.7
# [553]	validation_0-rmse:30803.2
# [554]	validation_0-rmse:30792.2
# [555]	validation_0-rmse:30786
# [556]	validation_0-rmse:30781.5
# [557]	validation_0-rmse:30791
# [558]	validation_0-rmse:30780.3
# [559]	validation_0-rmse:30762.9
# [560]	validation_0-rmse:30764.6
# [561]	validation_0-rmse:30758.6
# [562]	validation_0-rmse:30760.3
# [563]	validation_0-rmse:30744.4
# [564]	validation_0-rmse:30754.1
# [565]	validation_0-rmse:30750.1
# [566]	validation_0-rmse:30732.3
# [567]	validation_0-rmse:30725.3
# [568]	validation_0-rmse:30730
# [569]	validation_0-rmse:30742.3
# [570]	validation_0-rmse:30732
# [571]	validation_0-rmse:30728.3
# [572]	validation_0-rmse:30738
# Stopping. Best iteration:
# [567]	validation_0-rmse:30725.3
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.01, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=3000,
#        n_jobs=4, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
rst = my_model.evals_result()
n_estimators = len(rst['validation_0']['rmse'])-early_stop_rounds
n_estimators
# Out:
# 567

# %%
predictions = my_model.predict(test_X)
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, test_y)))
# Out:
# Mean Absolute Error : 17203.5640625

# %% [markdown]
# #### n_jobs
# set the parameter n_jobs equal to the number of cores

# %% [markdown]
# ### Pipelines & Cross Validation

# %%
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score

my_pipeline = make_pipeline(Imputer(), XGBRegressor(n_estimators=n_estimators, learning_rate=0.01,n_jobs=4))

scores = cross_val_score(my_pipeline, X, y, scoring='neg_mean_absolute_error',cv=5)
print('CrosValidation MAE : %2f' %(-1 * scores.mean()))

# %% [markdown]
# ### Partial Dependence Plot

# %%
from sklearn.ensemble import GradientBoostingRegressor
my_model = GradientBoostingRegressor()
my_model.fit(train_X,train_y)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
predictions = my_model.predict(test_X)
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, test_y)))
# Out:
# Mean Absolute Error : 16312.216166909051

# %%
from sklearn.ensemble.partial_dependence import partial_dependence, plot_partial_dependence

my_plots = plot_partial_dependence(my_model,       
                                   features=[0,1,2], # column numbers of plots we want to show
                                   X=train_X,            # raw predictors data.
                                   feature_names=['Distance', 'Landsize', 'BuildingArea'], # labels on graphs
                                   grid_resolution=50) # number of values to plot on x axis
