# %%
import pandas as pd
from sklearn.preprocessing import Imputer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data = train_data.dropna(axis=0, how='any',subset=['SalePrice'])
y = train_data.SalePrice
X = train_data.drop(['SalePrice'],axis=1).select_dtypes(exclude=['object'])

test_data = test_data.select_dtypes(exclude=['object'])

# %% [markdown]
# ## Handling Missing Data

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.25)

# %%
def missing_data_marker(df):
    cols_with_missing = (col for col in df.columns if df[col].isnull().any())
    for col in cols_with_missing:
        df[col+'_was_missing'] = df[col].isnull()
    return df

# %%
train_X = missing_data_marker(train_X)
test_X = missing_data_marker(test_X)
# Out:
# C:\Users\JialiangShi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
from sklearn.preprocessing import Imputer

my_imputer = Imputer()
train_X = my_imputer.fit_transform(train_X)
test_X = my_imputer.transform(test_X)

# %% [markdown]
# ## Model Tuning

# %% [markdown]
# #### n_estimators / early_stopping_rounds & learning_rate

# %% [markdown]
# #### n_jobs -  equal to the number of cores

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor(n_estimators=3000, learning_rate=0.01, n_jobs=4)
early_stopping_rounds = 5
my_model.fit(train_X, train_y, early_stopping_rounds=early_stopping_rounds, 
             eval_set=[(test_X, test_y)], verbose=True)
# Out:
# [0]	validation_0-rmse:195530
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:193697
# [2]	validation_0-rmse:191883
# [3]	validation_0-rmse:190095
# [4]	validation_0-rmse:188318
# [5]	validation_0-rmse:186579
# [6]	validation_0-rmse:184834
# [7]	validation_0-rmse:183081
# [8]	validation_0-rmse:181395
# [9]	validation_0-rmse:179665
# [10]	validation_0-rmse:177981
# [11]	validation_0-rmse:176299
# [12]	validation_0-rmse:174666
# [13]	validation_0-rmse:173048
# [14]	validation_0-rmse:171397
# [15]	validation_0-rmse:169784
# [16]	validation_0-rmse:168218
# [17]	validation_0-rmse:166666
# [18]	validation_0-rmse:165102
# [19]	validation_0-rmse:163561
# [20]	validation_0-rmse:162071
# [21]	validation_0-rmse:160527
# [22]	validation_0-rmse:159062
# [23]	validation_0-rmse:157558
# [24]	validation_0-rmse:156127
# [25]	validation_0-rmse:154679
# [26]	validation_0-rmse:153223
# [27]	validation_0-rmse:151834
# [28]	validation_0-rmse:150453
# [29]	validation_0-rmse:149044
# [30]	validation_0-rmse:147667
# [31]	validation_0-rmse:146347
# [32]	validation_0-rmse:144969
# [33]	validation_0-rmse:143670
# [34]	validation_0-rmse:142379
# [35]	validation_0-rmse:141044
# [36]	validation_0-rmse:139780
# [37]	validation_0-rmse:138506
# [38]	validation_0-rmse:137219
# [39]	validation_0-rmse:135974
# [40]	validation_0-rmse:134773
# [41]	validation_0-rmse:133515
# [42]	validation_0-rmse:132339
# [43]	validation_0-rmse:131139
# [44]	validation_0-rmse:129927
# [45]	validation_0-rmse:128765
# [46]	validation_0-rmse:127615
# [47]	validation_0-rmse:126488
# [48]	validation_0-rmse:125327
# [49]	validation_0-rmse:124212
# [50]	validation_0-rmse:123103
# [51]	validation_0-rmse:122008
# [52]	validation_0-rmse:120931
# [53]	validation_0-rmse:119845
# [54]	validation_0-rmse:118784
# [55]	validation_0-rmse:117727
# [56]	validation_0-rmse:116662
# [57]	validation_0-rmse:115619
# [58]	validation_0-rmse:114586
# [59]	validation_0-rmse:113578
# [60]	validation_0-rmse:112573
# [61]	validation_0-rmse:111582
# [62]	validation_0-rmse:110591
# [63]	validation_0-rmse:109630
# [64]	validation_0-rmse:108663
# [65]	validation_0-rmse:107729
# [66]	validation_0-rmse:106781
# [67]	validation_0-rmse:105844
# [68]	validation_0-rmse:104921
# [69]	validation_0-rmse:103988
# [70]	validation_0-rmse:103080
# [71]	validation_0-rmse:102180
# [72]	validation_0-rmse:101276
# [73]	validation_0-rmse:100431
# [74]	validation_0-rmse:99558.3
# [75]	validation_0-rmse:98700.1
# [76]	validation_0-rmse:97832.9
# [77]	validation_0-rmse:96982.8
# [78]	validation_0-rmse:96149.5
# [79]	validation_0-rmse:95334.5
# [80]	validation_0-rmse:94528.6
# [81]	validation_0-rmse:93703.9
# [82]	validation_0-rmse:92916.5
# [83]	validation_0-rmse:92116.2
# [84]	validation_0-rmse:91344.4
# [85]	validation_0-rmse:90581.1
# [86]	validation_0-rmse:89823.8
# [87]	validation_0-rmse:89070.3
# [88]	validation_0-rmse:88314.6
# [89]	validation_0-rmse:87571.6
# [90]	validation_0-rmse:86823.6
# [91]	validation_0-rmse:86108.5
# [92]	validation_0-rmse:85392.2
# [93]	validation_0-rmse:84685.4
# [94]	validation_0-rmse:83981.8
# [95]	validation_0-rmse:83298
# [96]	validation_0-rmse:82621.2
# [97]	validation_0-rmse:81952.3
# [98]	validation_0-rmse:81278.2
# [99]	validation_0-rmse:80597.7
# [100]	validation_0-rmse:79941.2
# [101]	validation_0-rmse:79298.8
# [102]	validation_0-rmse:78665.6
# [103]	validation_0-rmse:78026.8
# [104]	validation_0-rmse:77398.6
# [105]	validation_0-rmse:76769.5
# [106]	validation_0-rmse:76157.6
# [107]	validation_0-rmse:75562
# [108]	validation_0-rmse:74970.6
# [109]	validation_0-rmse:74382.3
# [110]	validation_0-rmse:73773.7
# [111]	validation_0-rmse:73173.5
# [112]	validation_0-rmse:72613
# [113]	validation_0-rmse:72032.6
# [114]	validation_0-rmse:71476.9
# [115]	validation_0-rmse:70912.5
# [116]	validation_0-rmse:70370.8
# [117]	validation_0-rmse:69835.2
# [118]	validation_0-rmse:69277.3
# [119]	validation_0-rmse:68758.5
# [120]	validation_0-rmse:68210.9
# [121]	validation_0-rmse:67695.4
# [122]	validation_0-rmse:67167.5
# [123]	validation_0-rmse:66663.8
# [124]	validation_0-rmse:66142.6
# [125]	validation_0-rmse:65653
# [126]	validation_0-rmse:65140
# [127]	validation_0-rmse:64654
# [128]	validation_0-rmse:64155.1
# [129]	validation_0-rmse:63691.7
# [130]	validation_0-rmse:63226.9
# [131]	validation_0-rmse:62747.7
# [132]	validation_0-rmse:62298.5
# [133]	validation_0-rmse:61858.9
# [134]	validation_0-rmse:61418
# [135]	validation_0-rmse:60984.8
# [136]	validation_0-rmse:60523.7
# [137]	validation_0-rmse:60100.4
# [138]	validation_0-rmse:59655.6
# [139]	validation_0-rmse:59246.2
# [140]	validation_0-rmse:58840.2
# [141]	validation_0-rmse:58415.7
# [142]	validation_0-rmse:57985.2
# [143]	validation_0-rmse:57589.5
# [144]	validation_0-rmse:57201.6
# [145]	validation_0-rmse:56792.7
# [146]	validation_0-rmse:56380.4
# [147]	validation_0-rmse:56009.1
# [148]	validation_0-rmse:55636.9
# [149]	validation_0-rmse:55247.9
# [150]	validation_0-rmse:54887.9
# [151]	validation_0-rmse:54526.5
# [152]	validation_0-rmse:54169.3
# [153]	validation_0-rmse:53804.2
# [154]	validation_0-rmse:53455.7
# [155]	validation_0-rmse:53087.9
# [156]	validation_0-rmse:52730.2
# [157]	validation_0-rmse:52394.5
# [158]	validation_0-rmse:52063.1
# [159]	validation_0-rmse:51713
# [160]	validation_0-rmse:51361.9
# [161]	validation_0-rmse:51045.1
# [162]	validation_0-rmse:50706.3
# [163]	validation_0-rmse:50379.8
# [164]	validation_0-rmse:50045.1
# [165]	validation_0-rmse:49739.1
# [166]	validation_0-rmse:49441.7
# [167]	validation_0-rmse:49120
# [168]	validation_0-rmse:48800.5
# [169]	validation_0-rmse:48511.5
# [170]	validation_0-rmse:48221.8
# [171]	validation_0-rmse:47913.4
# [172]	validation_0-rmse:47630.3
# [173]	validation_0-rmse:47351.4
# [174]	validation_0-rmse:47058.5
# [175]	validation_0-rmse:46781.9
# [176]	validation_0-rmse:46492.2
# [177]	validation_0-rmse:46214.1
# [178]	validation_0-rmse:45953.9
# [179]	validation_0-rmse:45678.1
# [180]	validation_0-rmse:45422.3
# [181]	validation_0-rmse:45153.9
# [182]	validation_0-rmse:44887.8
# [183]	validation_0-rmse:44638.7
# [184]	validation_0-rmse:44383.8
# [185]	validation_0-rmse:44139.2
# [186]	validation_0-rmse:43881.4
# [187]	validation_0-rmse:43643.7
# [188]	validation_0-rmse:43401.7
# [189]	validation_0-rmse:43156.6
# [190]	validation_0-rmse:42930.4
# [191]	validation_0-rmse:42691.4
# [192]	validation_0-rmse:42470.3
# [193]	validation_0-rmse:42244.8
# [194]	validation_0-rmse:42026.8
# [195]	validation_0-rmse:41795.1
# [196]	validation_0-rmse:41586.2
# [197]	validation_0-rmse:41372.4
# [198]	validation_0-rmse:41152.9
# [199]	validation_0-rmse:40941.4
# [200]	validation_0-rmse:40734
# [201]	validation_0-rmse:40522.7
# [202]	validation_0-rmse:40313.4
# [203]	validation_0-rmse:40112.2
# [204]	validation_0-rmse:39912.9
# [205]	validation_0-rmse:39727.2
# [206]	validation_0-rmse:39547.7
# [207]	validation_0-rmse:39354.3
# [208]	validation_0-rmse:39156.5
# [209]	validation_0-rmse:38972.8
# [210]	validation_0-rmse:38779.5
# [211]	validation_0-rmse:38611.7
# [212]	validation_0-rmse:38444.8
# [213]	validation_0-rmse:38264.8
# [214]	validation_0-rmse:38099
# [215]	validation_0-rmse:37924.7
# [216]	validation_0-rmse:37766.9
# [217]	validation_0-rmse:37590.7
# [218]	validation_0-rmse:37435.9
# [219]	validation_0-rmse:37270.9
# [220]	validation_0-rmse:37108.5
# [221]	validation_0-rmse:36947.3
# [222]	validation_0-rmse:36800.4
# [223]	validation_0-rmse:36649.9
# [224]	validation_0-rmse:36495.2
# [225]	validation_0-rmse:36352.6
# [226]	validation_0-rmse:36200.7
# [227]	validation_0-rmse:36053
# [228]	validation_0-rmse:35920.5
# [229]	validation_0-rmse:35768.5
# [230]	validation_0-rmse:35635.6
# [231]	validation_0-rmse:35497.6
# [232]	validation_0-rmse:35354.7
# [233]	validation_0-rmse:35220.8
# [234]	validation_0-rmse:35083.9
# [235]	validation_0-rmse:34951
# [236]	validation_0-rmse:34822.4
# [237]	validation_0-rmse:34696.3
# [238]	validation_0-rmse:34566.3
# [239]	validation_0-rmse:34443.1
# [240]	validation_0-rmse:34319.9
# [241]	validation_0-rmse:34191.7
# [242]	validation_0-rmse:34073.1
# [243]	validation_0-rmse:33956.7
# [244]	validation_0-rmse:33836.8
# [245]	validation_0-rmse:33715.5
# [246]	validation_0-rmse:33585.4
# [247]	validation_0-rmse:33467.6
# [248]	validation_0-rmse:33359.7
# [249]	validation_0-rmse:33251.8
# [250]	validation_0-rmse:33128.1
# [251]	validation_0-rmse:33022.6
# [252]	validation_0-rmse:32902.2
# [253]	validation_0-rmse:32799.9
# [254]	validation_0-rmse:32682.7
# [255]	validation_0-rmse:32582.8
# [256]	validation_0-rmse:32490.1
# [257]	validation_0-rmse:32376.2
# [258]	validation_0-rmse:32281.5
# [259]	validation_0-rmse:32186.8
# [260]	validation_0-rmse:32087.2
# [261]	validation_0-rmse:32000
# [262]	validation_0-rmse:31903
# [263]	validation_0-rmse:31815.6
# [264]	validation_0-rmse:31713.3
# [265]	validation_0-rmse:31626.6
# [266]	validation_0-rmse:31540.9
# [267]	validation_0-rmse:31451.9
# [268]	validation_0-rmse:31374.8
# [269]	validation_0-rmse:31290.1
# [270]	validation_0-rmse:31210.9
# [271]	validation_0-rmse:31111.3
# [272]	validation_0-rmse:31045.9
# [273]	validation_0-rmse:30963.8
# [274]	validation_0-rmse:30886.5
# [275]	validation_0-rmse:30798.1
# [276]	validation_0-rmse:30729.2
# [277]	validation_0-rmse:30666.2
# [278]	validation_0-rmse:30592.9
# [279]	validation_0-rmse:30521.8
# [280]	validation_0-rmse:30452.7
# [281]	validation_0-rmse:30367
# [282]	validation_0-rmse:30311.5
# [283]	validation_0-rmse:30246.8
# [284]	validation_0-rmse:30187
# [285]	validation_0-rmse:30121.2
# [286]	validation_0-rmse:30058.4
# [287]	validation_0-rmse:30002
# [288]	validation_0-rmse:29940.8
# [289]	validation_0-rmse:29877.9
# [290]	validation_0-rmse:29824.2
# [291]	validation_0-rmse:29762.6
# [292]	validation_0-rmse:29689.9
# [293]	validation_0-rmse:29627.5
# [294]	validation_0-rmse:29568.5
# [295]	validation_0-rmse:29515.1
# [296]	validation_0-rmse:29463.8
# [297]	validation_0-rmse:29414
# [298]	validation_0-rmse:29360.6
# [299]	validation_0-rmse:29296.3
# [300]	validation_0-rmse:29234
# [301]	validation_0-rmse:29182
# [302]	validation_0-rmse:29140
# [303]	validation_0-rmse:29087.8
# [304]	validation_0-rmse:29039.5
# [305]	validation_0-rmse:28985.1
# [306]	validation_0-rmse:28935.1
# [307]	validation_0-rmse:28889.7
# [308]	validation_0-rmse:28841.2
# [309]	validation_0-rmse:28791.1
# [310]	validation_0-rmse:28745.2
# [311]	validation_0-rmse:28701.1
# [312]	validation_0-rmse:28653.4
# [313]	validation_0-rmse:28601.1
# [314]	validation_0-rmse:28554.9
# [315]	validation_0-rmse:28513.5
# [316]	validation_0-rmse:28474.3
# [317]	validation_0-rmse:28429.8
# [318]	validation_0-rmse:28405.3
# [319]	validation_0-rmse:28362.2
# [320]	validation_0-rmse:28314.1
# [321]	validation_0-rmse:28264.1
# [322]	validation_0-rmse:28222.6
# [323]	validation_0-rmse:28179.5
# [324]	validation_0-rmse:28143.1
# [325]	validation_0-rmse:28104.1
# [326]	validation_0-rmse:28059.4
# [327]	validation_0-rmse:28022.3
# [328]	validation_0-rmse:27983.5
# [329]	validation_0-rmse:27942.9
# [330]	validation_0-rmse:27899.6
# [331]	validation_0-rmse:27861.2
# [332]	validation_0-rmse:27827.9
# [333]	validation_0-rmse:27790.7
# [334]	validation_0-rmse:27752.5
# [335]	validation_0-rmse:27718.6
# [336]	validation_0-rmse:27679.5
# [337]	validation_0-rmse:27649
# [338]	validation_0-rmse:27630.5
# [339]	validation_0-rmse:27598.3
# [340]	validation_0-rmse:27563.3
# [341]	validation_0-rmse:27528.3
# [342]	validation_0-rmse:27495.2
# [343]	validation_0-rmse:27460.8
# [344]	validation_0-rmse:27432.3
# [345]	validation_0-rmse:27392.9
# [346]	validation_0-rmse:27359.7
# [347]	validation_0-rmse:27330.8
# [348]	validation_0-rmse:27304.2
# [349]	validation_0-rmse:27272.4
# [350]	validation_0-rmse:27243.4
# [351]	validation_0-rmse:27206.6
# [352]	validation_0-rmse:27170
# [353]	validation_0-rmse:27138.6
# [354]	validation_0-rmse:27112.1
# [355]	validation_0-rmse:27086
# [356]	validation_0-rmse:27053.3
# [357]	validation_0-rmse:27025.7
# [358]	validation_0-rmse:26998.5
# [359]	validation_0-rmse:26972.1
# [360]	validation_0-rmse:26943.7
# [361]	validation_0-rmse:26911.2
# [362]	validation_0-rmse:26887.6
# [363]	validation_0-rmse:26862.3
# [364]	validation_0-rmse:26837.7
# [365]	validation_0-rmse:26814.7
# [366]	validation_0-rmse:26788.2
# [367]	validation_0-rmse:26757.5
# [368]	validation_0-rmse:26735.9
# [369]	validation_0-rmse:26715
# [370]	validation_0-rmse:26688.2
# [371]	validation_0-rmse:26662.4
# [372]	validation_0-rmse:26633.3
# [373]	validation_0-rmse:26608.9
# [374]	validation_0-rmse:26580.5
# [375]	validation_0-rmse:26566.3
# [376]	validation_0-rmse:26547
# [377]	validation_0-rmse:26523
# [378]	validation_0-rmse:26501.5
# [379]	validation_0-rmse:26476.4
# [380]	validation_0-rmse:26460.8
# [381]	validation_0-rmse:26442
# [382]	validation_0-rmse:26419.2
# [383]	validation_0-rmse:26406.1
# [384]	validation_0-rmse:26388.3
# [385]	validation_0-rmse:26366.9
# [386]	validation_0-rmse:26349.2
# [387]	validation_0-rmse:26327.3
# [388]	validation_0-rmse:26302
# [389]	validation_0-rmse:26280.7
# [390]	validation_0-rmse:26262.1
# [391]	validation_0-rmse:26242.9
# [392]	validation_0-rmse:26232.6
# [393]	validation_0-rmse:26209.9
# [394]	validation_0-rmse:26189.8
# [395]	validation_0-rmse:26179.3
# [396]	validation_0-rmse:26168.5
# [397]	validation_0-rmse:26140.5
# [398]	validation_0-rmse:26115.4
# [399]	validation_0-rmse:26095.9
# [400]	validation_0-rmse:26073.4
# [401]	validation_0-rmse:26052.2
# [402]	validation_0-rmse:26033.9
# [403]	validation_0-rmse:26015.6
# [404]	validation_0-rmse:25994
# [405]	validation_0-rmse:25980
# [406]	validation_0-rmse:25971.3
# [407]	validation_0-rmse:25948.5
# [408]	validation_0-rmse:25930.7
# [409]	validation_0-rmse:25916.5
# [410]	validation_0-rmse:25900.4
# [411]	validation_0-rmse:25875.5
# [412]	validation_0-rmse:25867.5
# [413]	validation_0-rmse:25851.9
# [414]	validation_0-rmse:25835.1
# [415]	validation_0-rmse:25813.7
# [416]	validation_0-rmse:25789.6
# [417]	validation_0-rmse:25775.7
# [418]	validation_0-rmse:25765.2
# [419]	validation_0-rmse:25753.7
# [420]	validation_0-rmse:25737.8
# [421]	validation_0-rmse:25717.3
# [422]	validation_0-rmse:25694.1
# [423]	validation_0-rmse:25679.8
# [424]	validation_0-rmse:25665.6
# [425]	validation_0-rmse:25642.3
# [426]	validation_0-rmse:25632.7
# [427]	validation_0-rmse:25621.2
# [428]	validation_0-rmse:25598.4
# [429]	validation_0-rmse:25588.9
# [430]	validation_0-rmse:25566.3
# [431]	validation_0-rmse:25547.1
# [432]	validation_0-rmse:25528
# [433]	validation_0-rmse:25519
# [434]	validation_0-rmse:25497.2
# [435]	validation_0-rmse:25480.9
# [436]	validation_0-rmse:25464.4
# [437]	validation_0-rmse:25443.3
# [438]	validation_0-rmse:25428
# [439]	validation_0-rmse:25419.6
# [440]	validation_0-rmse:25410.9
# [441]	validation_0-rmse:25393
# [442]	validation_0-rmse:25372.6
# [443]	validation_0-rmse:25357.3
# [444]	validation_0-rmse:25344.8
# [445]	validation_0-rmse:25324.3
# [446]	validation_0-rmse:25316.4
# [447]	validation_0-rmse:25299.7
# [448]	validation_0-rmse:25284.6
# [449]	validation_0-rmse:25271.2
# [450]	validation_0-rmse:25251.3
# [451]	validation_0-rmse:25243.9
# [452]	validation_0-rmse:25225.5
# [453]	validation_0-rmse:25213.8
# [454]	validation_0-rmse:25202.2
# [455]	validation_0-rmse:25186.6
# [456]	validation_0-rmse:25179.1
# [457]	validation_0-rmse:25170.1
# [458]	validation_0-rmse:25163.2
# [459]	validation_0-rmse:25145.7
# [460]	validation_0-rmse:25130.3
# [461]	validation_0-rmse:25116.5
# [462]	validation_0-rmse:25100.6
# [463]	validation_0-rmse:25092.4
# [464]	validation_0-rmse:25083.9
# [465]	validation_0-rmse:25073.1
# [466]	validation_0-rmse:25057.7
# [467]	validation_0-rmse:25049.8
# [468]	validation_0-rmse:25039.4
# [469]	validation_0-rmse:25033.3
# [470]	validation_0-rmse:25018.8
# [471]	validation_0-rmse:25012.5
# [472]	validation_0-rmse:25005
# [473]	validation_0-rmse:24984.1
# [474]	validation_0-rmse:24969.2
# [475]	validation_0-rmse:24961.4
# [476]	validation_0-rmse:24945.7
# [477]	validation_0-rmse:24931.8
# [478]	validation_0-rmse:24919
# [479]	validation_0-rmse:24909.1
# [480]	validation_0-rmse:24902.1
# [481]	validation_0-rmse:24898.6
# [482]	validation_0-rmse:24887.6
# [483]	validation_0-rmse:24881.8
# [484]	validation_0-rmse:24874.5
# [485]	validation_0-rmse:24862.2
# [486]	validation_0-rmse:24852.8
# [487]	validation_0-rmse:24842
# [488]	validation_0-rmse:24828.9
# [489]	validation_0-rmse:24822.4
# [490]	validation_0-rmse:24811.7
# [491]	validation_0-rmse:24798.8
# [492]	validation_0-rmse:24792.5
# [493]	validation_0-rmse:24775.1
# [494]	validation_0-rmse:24773.4
# [495]	validation_0-rmse:24763.1
# [496]	validation_0-rmse:24754.2
# [497]	validation_0-rmse:24738.3
# [498]	validation_0-rmse:24731.6
# [499]	validation_0-rmse:24721.6
# [500]	validation_0-rmse:24712.8
# [501]	validation_0-rmse:24696
# [502]	validation_0-rmse:24686.4
# [503]	validation_0-rmse:24676.1
# [504]	validation_0-rmse:24666
# [505]	validation_0-rmse:24654.2
# [506]	validation_0-rmse:24648.7
# [507]	validation_0-rmse:24636.9
# [508]	validation_0-rmse:24631.5
# [509]	validation_0-rmse:24630.4
# [510]	validation_0-rmse:24620.8
# [511]	validation_0-rmse:24612.6
# [512]	validation_0-rmse:24601.6
# [513]	validation_0-rmse:24587
# [514]	validation_0-rmse:24580.9
# [515]	validation_0-rmse:24569.6
# [516]	validation_0-rmse:24559.7
# [517]	validation_0-rmse:24551.6
# [518]	validation_0-rmse:24537.7
# [519]	validation_0-rmse:24524.9
# [520]	validation_0-rmse:24515
# [521]	validation_0-rmse:24514
# [522]	validation_0-rmse:24506.2
# [523]	validation_0-rmse:24504.6
# [524]	validation_0-rmse:24490.4
# [525]	validation_0-rmse:24484.8
# [526]	validation_0-rmse:24477
# [527]	validation_0-rmse:24463.7
# [528]	validation_0-rmse:24454.4
# [529]	validation_0-rmse:24446.9
# [530]	validation_0-rmse:24440
# [531]	validation_0-rmse:24429.7
# [532]	validation_0-rmse:24420.4
# [533]	validation_0-rmse:24410.3
# [534]	validation_0-rmse:24401.8
# [535]	validation_0-rmse:24397.5
# [536]	validation_0-rmse:24393.7
# [537]	validation_0-rmse:24387.3
# [538]	validation_0-rmse:24378.2
# [539]	validation_0-rmse:24369.6
# [540]	validation_0-rmse:24362.3
# [541]	validation_0-rmse:24354.6
# [542]	validation_0-rmse:24347.5
# [543]	validation_0-rmse:24345.7
# [544]	validation_0-rmse:24339.4
# [545]	validation_0-rmse:24329.4
# [546]	validation_0-rmse:24319.8
# [547]	validation_0-rmse:24312.7
# [548]	validation_0-rmse:24310
# [549]	validation_0-rmse:24302.1
# [550]	validation_0-rmse:24292.7
# [551]	validation_0-rmse:24283.6
# [552]	validation_0-rmse:24275.4
# [553]	validation_0-rmse:24265.9
# [554]	validation_0-rmse:24260.1
# [555]	validation_0-rmse:24260.8
# [556]	validation_0-rmse:24247.8
# [557]	validation_0-rmse:24241
# [558]	validation_0-rmse:24232.1
# [559]	validation_0-rmse:24231.3
# [560]	validation_0-rmse:24224.7
# [561]	validation_0-rmse:24217.5
# [562]	validation_0-rmse:24211
# [563]	validation_0-rmse:24203.6
# [564]	validation_0-rmse:24197
# [565]	validation_0-rmse:24194.8
# [566]	validation_0-rmse:24192.7
# [567]	validation_0-rmse:24185.2
# [568]	validation_0-rmse:24179.1
# [569]	validation_0-rmse:24178.4
# [570]	validation_0-rmse:24172.2
# [571]	validation_0-rmse:24160.3
# [572]	validation_0-rmse:24151.4
# [573]	validation_0-rmse:24146
# [574]	validation_0-rmse:24143.1
# [575]	validation_0-rmse:24141
# [576]	validation_0-rmse:24139.6
# [577]	validation_0-rmse:24130.2
# [578]	validation_0-rmse:24123
# [579]	validation_0-rmse:24115
# [580]	validation_0-rmse:24112.9
# [581]	validation_0-rmse:24104
# [582]	validation_0-rmse:24096.1
# [583]	validation_0-rmse:24088.4
# [584]	validation_0-rmse:24088
# [585]	validation_0-rmse:24082.5
# [586]	validation_0-rmse:24077.5
# [587]	validation_0-rmse:24072.6
# [588]	validation_0-rmse:24067.6
# [589]	validation_0-rmse:24061.4
# [590]	validation_0-rmse:24059.7
# [591]	validation_0-rmse:24051.3
# [592]	validation_0-rmse:24046.1
# [593]	validation_0-rmse:24040
# [594]	validation_0-rmse:24033.5
# [595]	validation_0-rmse:24028.4
# [596]	validation_0-rmse:24018.9
# [597]	validation_0-rmse:24014.6
# [598]	validation_0-rmse:24007.5
# [599]	validation_0-rmse:24008.7
# [600]	validation_0-rmse:24007.1
# [601]	validation_0-rmse:24005.8
# [602]	validation_0-rmse:24000.8
# [603]	validation_0-rmse:23996.4
# [604]	validation_0-rmse:23989.5
# [605]	validation_0-rmse:23982.3
# [606]	validation_0-rmse:23980.8
# [607]	validation_0-rmse:23979.7
# [608]	validation_0-rmse:23978.6
# [609]	validation_0-rmse:23974.4
# [610]	validation_0-rmse:23970.5
# [611]	validation_0-rmse:23963.2
# [612]	validation_0-rmse:23959.1
# [613]	validation_0-rmse:23958.2
# [614]	validation_0-rmse:23950.4
# [615]	validation_0-rmse:23943.4
# [616]	validation_0-rmse:23944.8
# [617]	validation_0-rmse:23940.8
# [618]	validation_0-rmse:23935.7
# [619]	validation_0-rmse:23929.9
# [620]	validation_0-rmse:23921.1
# [621]	validation_0-rmse:23915.4
# [622]	validation_0-rmse:23910.9
# [623]	validation_0-rmse:23903.4
# [624]	validation_0-rmse:23902.7
# [625]	validation_0-rmse:23895.7
# [626]	validation_0-rmse:23891.9
# [627]	validation_0-rmse:23893.4
# [628]	validation_0-rmse:23883.7
# [629]	validation_0-rmse:23878.5
# [630]	validation_0-rmse:23877.9
# [631]	validation_0-rmse:23872.1
# [632]	validation_0-rmse:23874.9
# [633]	validation_0-rmse:23871.2
# [634]	validation_0-rmse:23870.8
# [635]	validation_0-rmse:23863.6
# [636]	validation_0-rmse:23862.4
# [637]	validation_0-rmse:23859.4
# [638]	validation_0-rmse:23855.8
# [639]	validation_0-rmse:23852.8
# [640]	validation_0-rmse:23842.4
# [641]	validation_0-rmse:23838.9
# [642]	validation_0-rmse:23833.7
# [643]	validation_0-rmse:23834.2
# [644]	validation_0-rmse:23837.2
# [645]	validation_0-rmse:23832.9
# [646]	validation_0-rmse:23834.5
# [647]	validation_0-rmse:23833.5
# [648]	validation_0-rmse:23827.6
# [649]	validation_0-rmse:23827.7
# [650]	validation_0-rmse:23822.4
# [651]	validation_0-rmse:23815.5
# [652]	validation_0-rmse:23810.2
# [653]	validation_0-rmse:23809.2
# [654]	validation_0-rmse:23804.6
# [655]	validation_0-rmse:23798.1
# [656]	validation_0-rmse:23793.4
# [657]	validation_0-rmse:23794.5
# [658]	validation_0-rmse:23791.2
# [659]	validation_0-rmse:23790.2
# [660]	validation_0-rmse:23785.6
# [661]	validation_0-rmse:23785.6
# [662]	validation_0-rmse:23781.5
# [663]	validation_0-rmse:23776.4
# [664]	validation_0-rmse:23769.8
# [665]	validation_0-rmse:23760
# [666]	validation_0-rmse:23760.7
# [667]	validation_0-rmse:23756.3
# [668]	validation_0-rmse:23757.4
# [669]	validation_0-rmse:23757.4
# [670]	validation_0-rmse:23753.5
# [671]	validation_0-rmse:23748.6
# [672]	validation_0-rmse:23745.6
# [673]	validation_0-rmse:23741.1
# [674]	validation_0-rmse:23738.8
# [675]	validation_0-rmse:23735.9
# [676]	validation_0-rmse:23726.5
# [677]	validation_0-rmse:23722.1
# [678]	validation_0-rmse:23718.2
# [679]	validation_0-rmse:23714
# [680]	validation_0-rmse:23713.4
# [681]	validation_0-rmse:23716.7
# [682]	validation_0-rmse:23713.8
# [683]	validation_0-rmse:23708.4
# [684]	validation_0-rmse:23707.9
# [685]	validation_0-rmse:23711.1
# [686]	validation_0-rmse:23711
# [687]	validation_0-rmse:23705.1
# [688]	validation_0-rmse:23700.3
# [689]	validation_0-rmse:23695.5
# [690]	validation_0-rmse:23693.5
# [691]	validation_0-rmse:23689.5
# [692]	validation_0-rmse:23680.4
# [693]	validation_0-rmse:23677.7
# [694]	validation_0-rmse:23678.1
# [695]	validation_0-rmse:23676.7
# [696]	validation_0-rmse:23677.5
# [697]	validation_0-rmse:23674.3
# [698]	validation_0-rmse:23676.1
# [699]	validation_0-rmse:23676.3
# [700]	validation_0-rmse:23673.7
# [701]	validation_0-rmse:23672.3
# [702]	validation_0-rmse:23667.5
# [703]	validation_0-rmse:23667.8
# [704]	validation_0-rmse:23668.6
# [705]	validation_0-rmse:23659.9
# [706]	validation_0-rmse:23657.6
# [707]	validation_0-rmse:23654.5
# [708]	validation_0-rmse:23653.2
# [709]	validation_0-rmse:23653.8
# [710]	validation_0-rmse:23649.5
# [711]	validation_0-rmse:23647.2
# [712]	validation_0-rmse:23650.5
# [713]	validation_0-rmse:23646.7
# [714]	validation_0-rmse:23645.2
# [715]	validation_0-rmse:23645.3
# [716]	validation_0-rmse:23640.6
# [717]	validation_0-rmse:23635.7
# [718]	validation_0-rmse:23633.2
# [719]	validation_0-rmse:23631.9
# [720]	validation_0-rmse:23627.4
# [721]	validation_0-rmse:23628.3
# [722]	validation_0-rmse:23629.3
# [723]	validation_0-rmse:23628
# [724]	validation_0-rmse:23624.2
# [725]	validation_0-rmse:23625.1
# [726]	validation_0-rmse:23620.7
# [727]	validation_0-rmse:23619.5
# [728]	validation_0-rmse:23621
# [729]	validation_0-rmse:23616.6
# [730]	validation_0-rmse:23615.4
# [731]	validation_0-rmse:23612.4
# [732]	validation_0-rmse:23610.6
# [733]	validation_0-rmse:23611.6
# [734]	validation_0-rmse:23607.2
# [735]	validation_0-rmse:23606.1
# [736]	validation_0-rmse:23607.2
# [737]	validation_0-rmse:23605.4
# [738]	validation_0-rmse:23603.1
# [739]	validation_0-rmse:23604.1
# [740]	validation_0-rmse:23603
# [741]	validation_0-rmse:23598.8
# [742]	validation_0-rmse:23599.7
# [743]	validation_0-rmse:23598.1
# [744]	validation_0-rmse:23597.1
# [745]	validation_0-rmse:23597.6
# [746]	validation_0-rmse:23598.3
# [747]	validation_0-rmse:23599.3
# [748]	validation_0-rmse:23595.2
# [749]	validation_0-rmse:23594.2
# [750]	validation_0-rmse:23591.3
# [751]	validation_0-rmse:23588.2
# [752]	validation_0-rmse:23586.6
# [753]	validation_0-rmse:23581.2
# [754]	validation_0-rmse:23579.3
# [755]	validation_0-rmse:23578.4
# [756]	validation_0-rmse:23570.2
# [757]	validation_0-rmse:23569.1
# [758]	validation_0-rmse:23568.2
# [759]	validation_0-rmse:23568.9
# [760]	validation_0-rmse:23571.5
# [761]	validation_0-rmse:23570.1
# [762]	validation_0-rmse:23571.2
# [763]	validation_0-rmse:23569
# Stopping. Best iteration:
# [758]	validation_0-rmse:23568.2
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.01, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=3000,
#        n_jobs=4, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
rst = my_model.evals_result()
n_estimators = len(rst['validation_0']['rmse'])-early_stopping_rounds
n_estimators
# Out:
# 758

# %%
from sklearn.metrics import mean_absolute_error
predictions = my_model.predict(test_X)
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, test_y)))
# Out:
# Mean Absolute Error : 16495.702782534245

# %% [markdown]
# ### Retrain with all data

# %%
my_model = XGBRegressor(n_estimators=n_estimators, learning_rate=0.01,n_jobs=4)
my_model.fit(X,y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.01, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=758,
#        n_jobs=4, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
predictions = my_model.predict(test_data)

# %% [markdown]
# ### Partial Dependence Plot

# %%
from sklearn.ensemble import GradientBoostingRegressor
my_model = GradientBoostingRegressor()
my_model.fit(train_X,train_y)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
predictions = my_model.predict(test_X)
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, test_y)))
# Out:
# Mean Absolute Error : 16591.381436061318

# %%
from sklearn.ensemble.partial_dependence import partial_dependence, plot_partial_dependence

my_plots = plot_partial_dependence(my_model,       
                                   features=[0,1,2], # column numbers of plots we want to show
                                   X=train_X,            # raw predictors data.
                                   feature_names=['Distance', 'Landsize', 'BuildingArea'], # labels on graphs
                                   grid_resolution=50) # number of values to plot on x axis
